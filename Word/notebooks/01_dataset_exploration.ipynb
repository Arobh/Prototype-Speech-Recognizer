# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
file_path = "../data/yes/0a7c2a8d_nohash_0.wav"

# %%
data_path = "../data"

classes = os.listdir(data_path)

print(classes[:20])
# Out:
# ['up', 'bird', 'off', 'nine', 'house', 'down', 'bed', 'go', 'happy', 'six', 'five', '.DS_Store', 'no', '_background_noise_', 'cat', 'on', 'seven', 'three', 'wow', 'visual']

# %%
yes_files = os.listdir("../data/yes")

print("Number of 'yes' samples:", len(yes_files))
# Out:
# Number of 'yes' samples: 4044

# %%
audio, sr = librosa.load(file_path, sr=None)

print("Sampling Rate:", sr)
print("Audio length:", len(audio))
# Out:
# Sampling Rate: 16000
# Audio length: 16000

# %%
plt.figure(figsize=(12,4))
librosa.display.waveshow(audio, sr=sr)
plt.title("Speech Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
spectrogram = librosa.stft(audio)
spectrogram_db = librosa.amplitude_to_db(abs(spectrogram))

plt.figure(figsize=(12,4))
librosa.display.specshow(spectrogram_db, sr=sr, x_axis="time", y_axis="hz")
plt.colorbar()
plt.title("Spectrogram")
plt.show()

# %%
mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)

plt.figure(figsize=(10,4))
librosa.display.specshow(mfcc, x_axis="time")
plt.colorbar()
plt.title("MFCC")
plt.show()
